# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to the "***Sentiment Analysis and Classification Project***" project, the first and only project of the ***Natural Language Processing (NLP)*** course.
#
# This analysis will focus on using Natural Language techniques to find broad trends in the written thoughts of the customers.
# The goal in this project is to predict whether customers recommend the product they purchased using the information in their review text.
#
# One of the challenges in this project is to extract useful information from the *Review Text* variable using text mining techniques. The other challenge is that you need to convert text files into numeric feature vectors to run machine learning algorithms.
#
# At the end of this project, you will learn how to build sentiment classification models using Machine Learning algorithms (***Logistic Regression, Naive Bayes, Support Vector Machine, Random Forest*** and ***Ada Boosting***), **Deep Learning algorithms** and **BERT algorithm**.
#
# Before diving into the project, please take a look at the Determines and Tasks.
#
# - ***NOTE:*** *This tutorial assumes that you already know the basics of coding in Python and are familiar with the theory behind the algorithms mentioned above as well as NLP techniques.*

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
# The data is a collection of 22641 Rows and 10 column variables. Each row includes a written comment as well as additional customer information.
# Also each row corresponds to a customer review, and includes the variables:
#
#
# **Feature Information:**
#
# **Clothing ID:** Integer Categorical variable that refers to the specific piece being reviewed.
#
# **Age:** Positive Integer variable of the reviewers age.
#
# **Title:** String variable for the title of the review.
#
# **Review Text:** String variable for the review body.
#
# **Rating:** Positive Ordinal Integer variable for the product score granted by the customer from 1 Worst, to 5 Best.
#
# **Recommended IND:** Binary variable stating where the customer recommends the product where 1 is recommended, 0 is not recommended.
#
# **Positive Feedback Count:** Positive Integer documenting the number of other customers who found this review positive.
#
# **Division Name:** Categorical name of the product high level division.
#
# **Department Name:** Categorical name of the product department name.
#
# **Class Name:** Categorical name of the product class name.
#
# ---
#
# The basic goal in this project is to predict whether customers recommend the product they purchased using the information in their *Review Text*.
# Especially, it should be noted that the expectation in this project is to use only the "Review Text" variable and neglect the other ones.
# Of course, if you want, you can work on other variables individually.
#
# Project Structure is separated in five tasks: ***EDA, Feature Selection and Data Cleaning , Text Mining, Word Cloud*** and ***Sentiment Classification with Machine Learning, Deep Learning and BERT model***.
#
# Classically, you can start to know the data after doing the import and load operations.
# You need to do missing value detection for Review Text, which is the only variable you need to care about. You can drop other variables.
#
# You will need to apply ***noise removal*** and ***lexicon normalization*** processes by using the capabilities of the ***nltk*** library to the data set that is ready for text mining.
#
# Afterwards, you will implement ***Word Cloud*** as a visual analysis of word repetition.
#
# Finally, You will build models with five different algorithms and compare their performance. Thus, you will determine the algorithm that makes the most accurate emotion estimation by using the information obtained from the * Review Text * variable.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Tasks
#
# #### 1. Exploratory Data Analysis
#
# - Import Modules, Load Discover the Data
#
# #### 2. Feature Selection and Data Cleaning
#
# - Feature Selection and Rename Column Name
# - Missing Value Detection
#
# #### 3. Text Mining
#
# - Tokenization
# - Noise Removal
# - Lexicon Normalization
#
# #### 4. WordCloud - Repetition of Words
#
# - Detect Reviews
# - Collect Words
# - Create Word Cloud
#
#
# #### 5. Sentiment Classification with Machine Learning, Deep Learning and BERT Model
#
# - Train - Test Split
# - Vectorization
# - TF-IDF
# - Logistic Regression
# - Naive Bayes
# - Support Vector Machine
# - Random Forest
# - AdaBoost
# - Deep Learning Model
# - BERT Model
# - Model Comparison

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Sentiment analysis of women's clothes reviews
#
#
# In this project we used sentiment analysis to determined whether the product is recommended or not. We used different machine learning algorithms to get more accurate predictions. The following classification algorithms have been used: ML algorithms(Logistic Regression, Naive Bayes, Support Vector Machine (SVM), Random Forest and Ada Boosting), Deep learning algorithm and BERT algorithm. The dataset comes from Woman Clothing Review that can be find at (https://www.kaggle.com/nicapotato/womens-ecommerce-clothing-reviews.

# %% [markdown]
# ## 1. Exploratory Data Analysis

# %% [markdown]
# ### Import Libraries, Load and Discover the Data

# %%
# !pip install -q tf-models-official
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 18.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.2/241.2 kB 20.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 26.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.8/489.8 MB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 74.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 36.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 66.1 MB/s eta 0:00:00
# ...

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 16.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 30.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 9.1 MB/s eta 0:00:00
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_confusion_matrix
from wordcloud import WordCloud

import pandas as pd
import numpy as np
import re

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.naive_bayes import BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import make_scorer
from sklearn.metrics import confusion_matrix, classification_report, f1_score, recall_score
from sklearn.metrics import accuracy_score, precision_score, roc_curve, auc
#from scikitplot.metrics import plot_roc, plot_precision_recall
from sklearn.metrics import average_precision_score

from sklearn.model_selection import cross_validate, GridSearchCV
from sklearn.experimental import enable_halving_search_cv
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Embedding, Dropout
from tensorflow.keras.optimizers import Adam

from official.nlp import optimization
from transformers import TFBertModel, BertTokenizer, BertModel

from keras import backend as K
from tensorflow.keras.layers import Input, Dropout, Dense, BatchNormalization
from tensorflow.keras import Model

# %%
#!pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.14.0-cp39-cp39-win_amd64.whl (2.1 kB)
# ...
#   Using cached tensorflow_intel-2.14.0-cp39-cp39-win_amd64.whl (284.1 MB)
# ...
#   Using cached absl_py-2.0.0-py3-none-any.whl (130 kB)
# ...
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# ...
#   Using cached libclang-16.0.6-py2.py3-none-win_amd64.whl (24.4 MB)
# ...
#   Using cached tensorboard-2.14.1-py3-none-any.whl (5.5 MB)
# ...
#   Using cached termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached tensorflow_estimator-2.14.0-py2.py3-none-any.whl (440 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached gast-0.5.4-py3-none-any.whl (19 kB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Using cached keras-2.14.0-py3-none-any.whl (1.7 MB)
# ...
#   Using cached ml_dtypes-0.2.0-cp39-cp39-win_amd64.whl (938 kB)
# ...
#   Using cached tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-win_amd64.whl (1.5 MB)
# ...

# %%
from sklearn.model_selection import HalvingGridSearchCV

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Setting up TPU

# %%
import os

# Note that the `tpu` argument is for Colab-only
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])

tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %% [markdown]
# ### Data Wrangling

# %%
df = pd.read_csv('/content/drive/MyDrive/Womens Clothing E-Commerce Reviews.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23486 non-null  int64
#  1   Clothing ID              23486 non-null  int64
#  2   Age                      23486 non-null  int64
#  3   Title                    19676 non-null  object
#  4   Review Text              22641 non-null  object
#  5   Rating                   23486 non-null  int64
#  6   Recommended IND          23486 non-null  int64
#  7   Positive Feedback Count  23486 non-null  int64
#  8   Division Name            23472 non-null  object
#  9   Department Name          23472 non-null  object
#  10  Class Name               23472 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 2.0+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0   Clothing ID           Age        Rating  \
# count  23486.000000  23486.000000  23486.000000  23486.000000
# mean   11742.500000    918.118709     43.198544      4.196032
# std     6779.968547    203.298980     12.279544      1.110031
# min        0.000000      0.000000     18.000000      1.000000
# 25%     5871.250000    861.000000     34.000000      4.000000
# 50%    11742.500000    936.000000     41.000000      5.000000
# 75%    17613.750000   1078.000000     52.000000      5.000000
# max    23485.000000   1205.000000     99.000000      5.000000
#
#        Recommended IND  Positive Feedback Count
# count     23486.000000             23486.000000
# mean          0.822362                 2.535936
# std           0.382216                 5.702202
# min           0.000000                 0.000000
# 25%           1.000000                 0.000000
# 50%           1.000000                 1.000000
# 75%           1.000000                 3.000000
# ...

# %%
df.shape
# Out:
# (23486, 11)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# Clothing ID                   0
# Age                           0
# Title                      3810
# Review Text                 845
# Rating                        0
# Recommended IND               0
# Positive Feedback Count       0
# Division Name                14
# Department Name              14
# Class Name                   14
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Check Proportion of Target Class Variable:

# %% [markdown]
# The target class variable is imbalanced, where "Recommended" values are more dominating then "Not Recommendation".

# %%
df['Recommended IND'].value_counts()
# Out:
# 1    19314
# 0     4172
# Name: Recommended IND, dtype: int64

# %%
df['Recommended IND'].value_counts().plot.pie(autopct = '%.2f%%');

# %% [markdown]
# ## 2. Feature Selection and Data Cleaning
#
# From now on, the DataFrame you will work with should contain two columns: **"Review Text"** and **"Recommended IND"**. You can do the missing value detection operations from now on. You can also rename the column names if you want.

# %% [markdown]
# ### Feature Selection and Rename Column Name

# %%
temp = df.copy()

# %%
temp.isnull().sum()
# Out:
# Unnamed: 0                    0
# Clothing ID                   0
# Age                           0
# Title                      2966
# Review Text                   0
# Rating                        0
# recommended                   0
# Positive Feedback Count       0
# Division Name                13
# Department Name              13
# Class Name                   13
# count                         0
# dtype: int64

# %%
#we cant synthesize reviews, so we drop them
temp = temp.dropna(axis=0,  how = 'all', subset=['Review Text'])

# %%
temp.isnull().sum()
# Out:
# Unnamed: 0                    0
# Clothing ID                   0
# Age                           0
# Title                      2966
# Review Text                   0
# Rating                        0
# recommended                   0
# Positive Feedback Count       0
# Division Name                13
# Department Name              13
# Class Name                   13
# count                         0
# dtype: int64

# %%
len(temp['Review Text'].iloc[0])
# Out:
# 53

# %%
#getting the number of words in every review
temp['count'] = temp['Review Text'].apply(lambda x: len(x.split(' ')))

# %%
temp['count'].min()
# Out:
# 2

# %%
#storing stop words for later use
stop_words = stopwords.words("english")
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %% [markdown]
# ### Visualization

# %%
temp.rename(columns={'Recommended IND': 'recommended'}, inplace=True)

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22641 entries, 0 to 23485
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               22641 non-null  int64
#  1   Clothing ID              22641 non-null  int64
#  2   Age                      22641 non-null  int64
#  3   Title                    19675 non-null  object
#  4   Review Text              22641 non-null  object
#  5   Rating                   22641 non-null  int64
#  6   recommended              22641 non-null  int64
#  7   Positive Feedback Count  22641 non-null  int64
#  8   Division Name            22628 non-null  object
#  9   Department Name          22628 non-null  object
#  10  Class Name               22628 non-null  object
#  11  count                    22641 non-null  int64
# dtypes: int64(7), object(5)
# memory usage: 2.2+ MB

# %% [markdown]
# Age segmentation means focusing on the age range most valuable to your product or service. Marketing demographic age brackets are usually 18-24, 25-34, 35-44, 45-54, 55-64, and 65 and older.

# %%
temp.Age.min()
# Out:
# 18

# %%
temp.Age.max()
# Out:
# 99

# %%
temp = temp.assign(demographic = temp['Age'])

# %%
#categorizing ages
bins = [18, 24, 34, 44, 54, 64, np.inf]
names = ['18-24', '25-34', '35-44', '45-54', '55-64', '64+']#less
temp['demographic'] = pd.cut(temp['Age'], bins, labels=names)
temp.demographic.value_counts()
# Out:
# 35-44    7433
# 25-34    4962
# 45-54    4944
# 55-64    3078
# 64+      1357
# 18-24     863
# Name: demographic, dtype: int64

# %%
sns.countplot(data = temp, x = 'demographic', hue = 'recommended');

# %% [markdown]
# - Most of the consumers are between 35 and 44 years old.
# - least consumers are between 18 to 24 years old.

# %%
def cleaning(data):


    #Removing upper brackets to keep negative auxiliary verbs in text
    data = data.replace("'", "")

    #Tokenize
    text_tokens = word_tokenize(data.lower())

    #Remove Puncs and numbers
    tokens_without_punc = [w for w in text_tokens if w.isalpha()]

    #Removing Stopwords
    tokens_without_sw = [t for t in tokens_without_punc if t not in stop_words]

    #lemma
    text_cleaned = [WordNetLemmatizer().lemmatize(t) for t in tokens_without_sw]


    #joining
    return " ".join( text_cleaned)

# %%
#storing clean text in a new column
prep_df = temp.copy()
prep_df['clean'] = prep_df['Review Text'].apply(cleaning)

# %%
prep_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22641 entries, 0 to 23485
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               22641 non-null  int64
#  1   Clothing ID              22641 non-null  int64
#  2   Age                      22641 non-null  int64
#  3   Title                    19675 non-null  object
#  4   Review Text              22641 non-null  object
#  5   Rating                   22641 non-null  int64
#  6   recommended              22641 non-null  int64
#  7   Positive Feedback Count  22641 non-null  int64
#  8   Division Name            22628 non-null  object
#  9   Department Name          22628 non-null  object
#  10  Class Name               22628 non-null  object
#  11  count                    22641 non-null  int64
#  12  demographic              22637 non-null  category
#  13  clean                    22641 non-null  object
# ...

# %%
prep_df = prep_df[['clean', 'recommended']]

# %%
prep_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22641 entries, 0 to 23485
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   clean        22641 non-null  object
#  1   recommended  22641 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 530.6+ KB

# %%
prep_df.isnull().sum()
# Out:
# clean          0
# recommended    0
# dtype: int64

# %%
prep_df.duplicated().sum()
# Out:
# 10

# %%
#delete duplications
prep_df.drop_duplicates(inplace = True)

# %%
prep_df.duplicated().sum()
# Out:
# 0

# %%
temp['Review Text']
# Out:
# 0        Absolutely wonderful - silky and sexy and comf...
# 1        Love this dress!  it's sooo pretty.  i happene...
# 2        I had such high hopes for this dress and reall...
# 3        I love, love, love this jumpsuit. it's fun, fl...
# 4        This shirt is very flattering to all due to th...
#                                ...
# 23481    I was very happy to snag this dress at such a ...
# 23482    It reminds me of maternity clothes. soft, stre...
# 23483    This fit well, but the top was very see throug...
# 23484    I bought this dress for a wedding i have this ...
# 23485    This dress in a lovely platinum is feminine an...
# Name: Review Text, Length: 22641, dtype: object

# %%
prep_df['clean']
# Out:
# 0              absolutely wonderful silky sexy comfortable
# 1        love dress sooo pretty happened find store im ...
# 2        high hope dress really wanted work initially o...
# 3        love love love jumpsuit fun flirty fabulous ev...
# 4        shirt flattering due adjustable front tie perf...
#                                ...
# 23481    happy snag dress great price easy slip flatter...
# 23482    reminds maternity clothes soft stretchy shiny ...
# 23483    fit well top see never would worked im glad ab...
# 23484    bought dress wedding summer cute unfortunately...
# 23485    dress lovely platinum feminine fit perfectly e...
# Name: clean, Length: 22631, dtype: object

# %% [markdown]
# Now I'm sure text cleaning was successful.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### Missing Value Detection

# %% [markdown]
# Did this step above.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 3. Text Mining
#
# Text is the most unstructured form of all the available data, therefore various types of noise are present in it. This means that the data is not readily analyzable without any pre-processing. The entire process of cleaning and standardization of text, making it noise-free and ready for analysis is known as **text preprocessing**.
#
# The three key steps of text preprocessing:
#
# - **Tokenization:**
# This step is one of the top priorities when it comes to working on text mining. Tokenization is essentially splitting a phrase, sentence, paragraph, or an entire text document into smaller units, such as individual words or terms. Each of these smaller units are called tokens.
#
# - **Noise Removal:**
# Any piece of text which is not relevant to the context of the data and the end-output can be specified as the noise.
# For example – language stopwords (commonly used words of a language – is, am, the, of, in etc), URLs or links, upper and lower case differentiation, punctuations and industry specific words. This step deals with removal of all types of noisy entities present in the text.
#
#
# - **Lexicon Normalization:**
# Another type of textual noise is about the multiple representations exhibited by single word.
# For example – “play”, “player”, “played”, “plays” and “playing” are the different variations of the word – “play”. Though they mean different things, contextually they all are similar. This step converts all the disparities of a word into their normalized form (also known as lemma).
# There are two methods of lexicon normalisation; **[Stemming or Lemmatization](https://www.guru99.com/stemming-lemmatization-python-nltk.html)**. Lemmatization is recommended for this case, because Lemmatization as this will return the root form of each word (rather than just stripping suffixes, which is stemming).
#
# As the first step change text to tokens and convertion all of the words to lower case.  Next remove punctuation, bad characters, numbers and stop words. The second step is aimed to normalization them throught the Lemmatization method.
#
#
# ***Note:*** *Use the functions of the ***[nltk Library](https://www.guru99.com/nltk-tutorial.html)*** for all the above operations.*

# %% [markdown]
# ### Tokenization, Noise Removal, Lexicon Normalization

# %% [markdown]
# Did cleaning above.

# %% [markdown]
# ## 4. WordCloud - Repetition of Words
#
# Now you'll create a Word Clouds for reviews, representing most common words in each target class.
#
# Word Cloud is a data visualization technique used for representing text data in which the size of each word indicates its frequency or importance. Significant textual data points can be highlighted using a word cloud.
#
# You are expected to create separate word clouds for positive and negative reviews. You can qualify a review as positive or negative, by looking at its recommended status. You may need to use capabilities of matplotlib for visualizations.
#
# You can follow the steps below:
#
# - Detect Reviews
# - Collect Words
# - Create Word Cloud

# %% [markdown]
# ### Detect Reviews (positive and negative separately)

# %% [markdown]
# WordCloud cells are done in my Jupyter environment while model training is done on Google Colab.

# %% [markdown]
# ### Collect Words (positive and negative separately)

# %% [markdown]
# I did WordCloud in Jupyter thats why I did not run it in colab because it might have import issues.

# %%
positive_words = prep_df.loc[prep_df['recommended'] == 1]

# %%
positive_words
# Out:
#                                                    clean  recommended
# 0            absolutely wonderful silky sexy comfortable            1
# 1      love dress sooo pretty happened find store im ...            1
# 3      love love love jumpsuit fun flirty fabulous ev...            1
# 4      shirt flattering due adjustable front tie perf...            1
# 6      aded basket hte last mintue see would look lik...            1
# ...                                                  ...          ...
# 23479  wasnt sure ordering skirt couldnt see person f...            1
# 23481  happy snag dress great price easy slip flatter...            1
# 23482  reminds maternity clothes soft stretchy shiny ...            1
# 23484  bought dress wedding summer cute unfortunately...            1
# 23485  dress lovely platinum feminine fit perfectly e...            1
#
# [18531 rows x 2 columns]

# %%
positives = " ".join(positive_words['clean'])

# %%
negative_words = prep_df.loc[prep_df['recommended'] == 0]

# %%
negatives = " ".join(negative_words['clean'])

# %% [markdown]
# ### Create Word Cloud (for most common words in recommended not recommended reviews separately)

# %%
plt.axis("off")
#making the wordCloud
wordcloud_p = WordCloud( background_color="white", width=800, height=400).generate(positives)
plt.tight_layout(pad=0)
#displaying wordCloud
plt.imshow(wordcloud_p, interpolation='bilinear')
plt.show()

# %%
#to fix 'ImageDraw' object has no attribute 'textbbox'
#python -m pip install Pillow==9.5.0

# %%
plt.axis("off")
#making the wordCloud
wordcloud_n = WordCloud( background_color="white", width=800, height=400).generate(negatives)
plt.tight_layout(pad=0)
#displaying wordCloud
plt.imshow(wordcloud_n, interpolation='bilinear')
plt.show()

# %% [markdown]
# ## 5. Sentiment Classification with Machine Learning, Deep Learning and BERT model
#
# Before moving on to modeling, as data preprocessing steps you will need to perform **[vectorization](https://machinelearningmastery.com/prepare-text-data-machine-learning-scikit-learn/)** and **train-test split**. You have performed many times train test split process before.
# But you will perform the vectorization for the first time.
#
# Machine learning algorithms most often take numeric feature vectors as input. Thus, when working with text documents, you need a way to convert each document into a numeric vector. This process is known as text vectorization. Commonly used vectorization approach that you will use here is to represent each text as a vector of word counts.
#
# At this moment, you have your review text column as a token (which has no punctuations and stopwords). You can use Scikit-learn’s CountVectorizer to convert the text collection into a matrix of token counts. You can imagine this resulting matrix as a 2-D matrix, where each row is a unique word, and each column is a review.
#
# Train all models using TFIDF and Count vectorizer data.
#
# **For Deep learning model, use embedding layer for all words.**
#
# **For BERT model, use TF tensor**
#
# After performing data preprocessing, build your models using following classification algorithms:
#
# - Logistic Regression,
# - Naive Bayes,
# - Support Vector Machine,
# - Random Forest,
# - Ada Boosting
# - Deep Learning Model
# - BERT Model

# %% [markdown]
# ### Train - Test Split

# %% [markdown]
# To run machine learning algorithms we need to convert text files into numerical feature vectors. We will use bag of words model for our analysis.
#
# First we spliting the data into train and test sets:

# %%
X = prep_df["clean"]
y = prep_df["recommended"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# In the next step we create a numerical feature vector for each document:

# %% [markdown]
# ### Count Vectorization

# %%
vectorizer = CountVectorizer(preprocessor=cleaning, min_df=3)

X_train_count = vectorizer.fit_transform(X_train)
X_test_count = vectorizer.transform(X_test)

# %%
df_train_count_vic = pd.DataFrame(X_train_count.toarray(), columns = vectorizer.get_feature_names_out(),
                              index= X_train.index)
df_test_count_vic = pd.DataFrame(X_test_count.toarray(), columns = vectorizer.get_feature_names_out(),
                              index= X_test.index)

# %% [markdown]
# ### TF-IDF

# %%
tf_idf_vectorizer = TfidfVectorizer()

X_train_tf_idf = tf_idf_vectorizer.fit_transform(X_train)
X_test_tf_idf = tf_idf_vectorizer.transform(X_test)

# %%
df_train_tfidf = pd.DataFrame(X_train_tf_idf.toarray(), columns = tf_idf_vectorizer.get_feature_names_out(),
                              index= X_train.index)
df_test_tfidf = pd.DataFrame(X_test_tf_idf.toarray(), columns = tf_idf_vectorizer.get_feature_names_out(),
                              index= X_test.index)

# %% [markdown]
# ### Eval Function

# %%
#confusion matrix
def eval_metric(model, X_train, y_train, X_test, y_test, dl = False):

    """ to get the metrics for the model """
    if dl == True:
        y_train_pred = model.predict(X_train) > 0.5
        y_pred = model.predict(X_test) > 0.5
    else:
        y_train_pred = model.predict(X_train)
        y_pred = model.predict(X_test)

    print("\tTest_Set\n")
    fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, y_pred), show_normed = True, figsize=(6, 6))
    plt.xlabel('Predictions', fontsize=18)
    plt.ylabel('Actuals', fontsize=18)
    plt.title('Confusion Matrix', fontsize=18)
    plt.show()
    print(classification_report(y_test, y_pred))
    print()
    print("\tTrain_Set\n")
    fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_train, y_train_pred), show_normed = True, figsize=(6, 6))
    plt.xlabel('Predictions', fontsize=18)
    plt.ylabel('Actuals', fontsize=18)
    plt.title('Confusion Matrix', fontsize=18)
    plt.show()
    print()
    print(classification_report(y_train, y_train_pred))

# %%
#roc curve
def roc_auc_plot(model, y_train, X_train, y_test, X_test):
    pred_train = model.predict(X_train).ravel()
    pred_test = model.predict(X_test).ravel()
    fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_train, pred_train)
    fpr_keras_test, tpr_keras_test, thresholds_keras_test = roc_curve(y_test, pred_test)


    auc_keras = auc(fpr_keras, tpr_keras)
    auc_keras_test = auc(fpr_keras_test, tpr_keras_test)


    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr_keras, tpr_keras, label='train (area = {:.3f})'.format(auc_keras))
    plt.plot(fpr_keras_test, tpr_keras_test, label='val (area = {:.3f})'.format(auc_keras_test))

    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.legend(loc='best')
    plt.show()

# %%
def eval_scores(model, X_train, y_train):
    scoring = {'accuracy': make_scorer(accuracy_score),
            'precision': make_scorer(precision_score, average=None, labels=[0]),
            'recall': make_scorer(recall_score, average=None, labels = [0]),
            'f1': make_scorer(f1_score, average=None, labels = [0])}
                                                                                # 5 -> stratification
    scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 5, return_train_score=True, n_jobs = -1)
    df_scores = pd.DataFrame(scores, index = range(1,6))
    return df_scores

# %%
def eval_scores_dl(y_true, y_pred):
  #for calculating average precision, recall, and f1-score on deep learning models
  precision_s = average_precision_score(y_true, y_pred)
  recall_s = recall_score(y_true, y_pred, average='weighted', labels=np.unique(y_pred))
  f1_s = f1_score(y_true, y_pred, average='weighted', labels=np.unique(y_pred))
  models_scores = pd.DataFrame({'f-1':[f1_s], 'precision':[precision_s], 'recall':[recall_s]})
  return models_scores

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ### CountVectorizer

# %%
logisitc_model = LogisticRegression(max_iter = 10000)
logisitc_model.fit(X_train_count, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
logistic_scores = eval_scores(logisitc_model, X_train_count, y_train)
logistic_scores.mean()[2:]
# Out:
# test_accuracy      0.883783
# train_accuracy     0.948603
# test_precision     0.709473
# train_precision    0.905662
# test_recall        0.607317
# train_recall       0.799619
# test_f1            0.654223
# train_f1           0.849324
# dtype: float64

# %%
eval_metric(logisitc_model, X_train_count, y_train, X_test_count, y_test)
# Out:
# 	Test_Set
#               precision    recall  f1-score   support
#
#            0       0.72      0.63      0.67       820
#            1       0.92      0.95      0.93      3707
#
#     accuracy                           0.89      4527
#    macro avg       0.82      0.79      0.80      4527
# weighted avg       0.88      0.89      0.88      4527
#
#
# 	Train_Set
#               precision    recall  f1-score   support
#
#            0       0.90      0.78      0.84      3280
#            1       0.95      0.98      0.97     14824
#
#     accuracy                           0.94     18104
#    macro avg       0.92      0.88      0.90     18104
# weighted avg       0.94      0.94      0.94     18104

# %%
roc_auc_plot(logisitc_model, y_train, X_train_count, y_test, X_test_count)

# %% [markdown]
# The model is slightly overfitted when using CountVectorizer.

# %% [markdown]
# ### TF-IDF

# %%
logisitc_model_tf = LogisticRegression(max_iter = 10000)
logisitc_model_tf.fit(X_train_tf_idf, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
logistic_scores_tf_idf = eval_scores(logisitc_model_tf, X_train_tf_idf, y_train)
logistic_scores_tf_idf.mean()[2:]
# Out:
# test_accuracy      0.886268
# train_accuracy     0.908915
# test_precision     0.796832
# train_precision    0.867916
# test_recall        0.499695
# train_recall       0.586509
# test_f1            0.614103
# train_f1           0.699982
# dtype: float64

# %%
eval_metric(logisitc_model_tf, X_train_tf_idf, y_train, X_test_tf_idf, y_test)
# Out:
# 	Test_Set
#               precision    recall  f1-score   support
#
#            0       0.79      0.54      0.64       820
#            1       0.91      0.97      0.94      3707
#
#     accuracy                           0.89      4527
#    macro avg       0.85      0.75      0.79      4527
# weighted avg       0.88      0.89      0.88      4527
#
#
# 	Train_Set
#               precision    recall  f1-score   support
#
#            0       0.86      0.60      0.71      3280
#            1       0.92      0.98      0.95     14824
#
#     accuracy                           0.91     18104
#    macro avg       0.89      0.79      0.83     18104
# weighted avg       0.91      0.91      0.90     18104

# %%
roc_auc_plot(logisitc_model_tf, y_train, X_train_tf_idf, y_test, X_test_tf_idf)

# %% [markdown]
# The model generalize well but there is room for improvement.

# %% [markdown]
# ### Gridsearch for Logistic Regression

# %%
parameters_lr = [{'penalty':['l2', 'l1'],'C': [0.1, 0.5, 1],
                    'class_weight':['balanced', {0:3, 1:1}],
                    'solver':['liblinear', 'saga'], 'max_iter':[10000]}]
logistic_model_gs = LogisticRegression()
f1_0 = make_scorer(f1_score, average=None, labels = [0])
grid_search_lr = HalvingGridSearchCV(logistic_model_gs, parameters_lr, max_resources=20, scoring = f1_0, cv = 5, n_jobs = -1
                              ,random_state=0)

#choose tf-idf because it did not overfit
grid_search_lr.fit(X_train_tf_idf, y_train)
best_accuracy_lr = grid_search_lr.best_score_
best_paramaeter_lr = grid_search_lr.best_params_
print("Best class 0 f1-score of LR: {:.2f} %".format(best_accuracy_lr.mean()*100))
print("Best Parameter of LR:", best_paramaeter_lr)
# Out:
# Best class 0 f1-score of LR: 47.33 %
# Best Parameter of LR: {'C': 0.1, 'class_weight': 'balanced', 'max_iter': 10000, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
logistic_scores_op = eval_scores(grid_search_lr, X_train_tf_idf, y_train)
logistic_scores_op.mean()[2:]
# Out:
# test_accuracy      0.826283
# train_accuracy     0.835837
# test_precision     0.514741
# train_precision    0.531550
# test_recall        0.840244
# train_recall       0.869360
# test_f1            0.637918
# train_f1           0.659195
# dtype: float64

# %%
eval_metric(grid_search_lr, X_train_tf_idf, y_train, X_test_tf_idf, y_test)
# Out:
# 	Test_Set
#               precision    recall  f1-score   support
#
#            0       0.47      0.81      0.59       820
#            1       0.95      0.80      0.87      3707
#
#     accuracy                           0.80      4527
#    macro avg       0.71      0.80      0.73      4527
# weighted avg       0.86      0.80      0.82      4527
#
#
# 	Train_Set
#               precision    recall  f1-score   support
#
#            0       0.49      0.84      0.62      3280
#            1       0.96      0.81      0.88     14824
#
#     accuracy                           0.81     18104
#    macro avg       0.72      0.82      0.75     18104
# weighted avg       0.87      0.81      0.83     18104

# %%
roc_auc_plot(grid_search_lr, y_train, X_train_tf_idf, y_test, X_test_tf_idf)

# %% [markdown]
# The recall for class 0 increased significantly and it improved in roc curve.

# %% [markdown]
# ## Naive Bayes
#
# ### Countvectorizer

# %%
nb_count = BernoulliNB()

# %%
nb_count.fit(X_train_count, y_train)
# Out:
# BernoulliNB()

# %%
nb_scores = eval_scores(nb_count, X_train_count, y_train)
nb_scores.mean()[2:]
# Out:
# test_accuracy      0.877265
# train_accuracy     0.901596
# test_precision     0.642721
# train_precision    0.701930
# test_recall        0.727134
# train_recall       0.794055
# test_f1            0.682225
# train_f1           0.745151
# dtype: float64

# %%
eval_metric(nb_count, X_train_count, y_train, X_test_count, y_test)
# Out:
# 	Test_Set
#               precision    recall  f1-score   support
#
#            0       0.63      0.72      0.67       820
#            1       0.94      0.91      0.92      3707
#
#     accuracy                           0.87      4527
#    macro avg       0.78      0.81      0.80      4527
# weighted avg       0.88      0.87      0.88      4527
#
#
# 	Train_Set
#               precision    recall  f1-score   support
#
#            0       0.69      0.80      0.74      3280
#            1       0.95      0.92      0.94     14824
#
#     accuracy                           0.90     18104
#    macro avg       0.82      0.86      0.84     18104
# weighted avg       0.91      0.90      0.90     18104

# %%
roc_auc_plot(nb_count, y_train, X_train_count, y_test, X_test_count)

# %% [markdown]
# ### TF-IDF

# %%
nb_count_tf = BernoulliNB()
nb_count_tf.fit(X_train_tf_idf, y_train)
# Out:
# BernoulliNB()

# %%
nb_scores_tf = eval_scores(nb_count_tf, X_train_tf_idf, y_train)
nb_scores_tf.mean()[2:]
# Out:
# test_accuracy      0.873343
# train_accuracy     0.905366
# test_precision     0.665782
# train_precision    0.760890
# test_recall        0.607317
# train_recall       0.696570
# test_f1            0.634895
# train_f1           0.727308
# dtype: float64

# %%
eval_metric(nb_count_tf, X_train_tf_idf, y_train, X_test_tf_idf, y_test)
# Out:
# 	Test_Set
#               precision    recall  f1-score   support
#
#            0       0.66      0.61      0.64       820
#            1       0.92      0.93      0.92      3707
#
#     accuracy                           0.87      4527
#    macro avg       0.79      0.77      0.78      4527
# weighted avg       0.87      0.87      0.87      4527
#
#
# 	Train_Set
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.73      3280
#            1       0.94      0.94      0.94     14824
#
#     accuracy                           0.90     18104
#    macro avg       0.84      0.83      0.84     18104
# weighted avg       0.90      0.90      0.90     18104

# %%
roc_auc_plot(nb_count_tf, y_train, X_train_tf_idf, y_test, X_test_tf_idf)

# %% [markdown]
# Both dataset perform well but Count Vectorizer is better.

# %% [markdown]
# ## Support Vector Machine (SVM)
#
# ### Countvectorizer

# %%
#increasing the max_iter to help the model converge
svm = SVC()
svm.fit(X_train_count, y_train)
# Out:
# SVC()

# %%
svm_scores = eval_scores(svm, X_train_count, y_train)
svm_scores.mean()[2:]
# Out:
# test_accuracy      0.885992
# train_accuracy     0.965947
# test_precision     0.803651
# train_precision    0.965979
# test_recall        0.490549
# train_recall       0.841692
# test_f1            0.609016
# train_f1           0.899560
# dtype: float64

# %%
eval_metric(svm, X_train_count, y_train, X_test_count, y_test)
# Out:
# 	Test_Set
#               precision    recall  f1-score   support
#
#            0       0.80      0.54      0.64       820
#            1       0.90      0.97      0.94      3707
#
#     accuracy                           0.89      4527
#    macro avg       0.85      0.75      0.79      4527
# weighted avg       0.89      0.89      0.88      4527
#
#
# 	Train_Set
#               precision    recall  f1-score   support
#
#            0       0.96      0.84      0.90      3280
#            1       0.97      0.99      0.98     14824
#
#     accuracy                           0.97     18104
#    macro avg       0.96      0.92      0.94     18104
# weighted avg       0.97      0.97      0.96     18104

# %%
roc_auc_plot(svm, y_train, X_train_count, y_test, X_test_count)

# %% [markdown]
# ### TD-IDF

# %%
svm_tf = SVC()
svm_tf.fit(X_train_tf_idf, y_train)
# Out:
# SVC()

# %%
svm_scores_tf = eval_scores(svm_tf, X_train_tf_idf, y_train)
svm_scores_tf.mean()[2:]
# Out:
# test_accuracy      0.887538
# train_accuracy     0.979549
# test_precision     0.797604
# train_precision    0.984757
# test_recall        0.508232
# train_recall       0.901067
# test_f1            0.620661
# train_f1           0.941054
# dtype: float64

# %%
eval_metric(svm_tf, X_train_tf_idf, y_train, X_test_tf_idf, y_test)
# Out:
# 	Test_Set
#               precision    recall  f1-score   support
#
#            0       0.80      0.55      0.65       820
#            1       0.91      0.97      0.94      3707
#
#     accuracy                           0.89      4527
#    macro avg       0.85      0.76      0.79      4527
# weighted avg       0.89      0.89      0.88      4527
#
#
# 	Train_Set
#               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94      3280
#            1       0.98      1.00      0.99     14824
#
#     accuracy                           0.98     18104
#    macro avg       0.98      0.95      0.96     18104
# weighted avg       0.98      0.98      0.98     18104

# %%
roc_auc_plot(svm_tf, y_train, X_train_tf_idf, y_test, X_test_tf_idf)

# %% [markdown]
# Since both are ovefitted with similar scores, we can choose whichever vectorizer for gridsearch.

# %% [markdown]
# ### Gridsearch for SVM

# %%
parameters_svm = [{'kernel':['linear','rbf','sigmoid','poly'] ,
                   'gamma':['scale', 'auto'],
                   'C': [0.01,0.1,1,10,1000],
                    'class_weight':['balanced', {0:3, 1:1}],
                  'max_iter':[100000]}]
svm_model_gs = SVC()
recall_0 = make_scorer(recall_score, average=None, labels = [0])
grid_search_svm = HalvingGridSearchCV(svm_model_gs, parameters_svm, max_resources=20,
                                     scoring = recall_0, cv = 5, n_jobs = -1, random_state=0)

grid_search_svm.fit(X_train_count, y_train)
best_accuracy_svm = grid_search_svm.best_score_
best_paramaeter_svm = grid_search_svm.best_params_
print("Best class 0 recall of svm: {:.2f} %".format(best_accuracy_svm.mean()*100))
print("Best Parameter of svm:", best_paramaeter_svm)
# Out:
# Best class 0 recall of svm: 100.00 %
# Best Parameter of svm: {'C': 1, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'rbf', 'max_iter': 100000}

# %%
svm_scores_gs = eval_scores(grid_search_svm, X_train_count, y_train)
svm_scores_gs.mean()[2:]
# Out:
# test_accuracy      0.694715
# train_accuracy     0.732723
# test_precision     0.479499
# train_precision    0.611737
# test_recall        0.626220
# train_recall       0.768140
# test_f1            0.420881
# train_f1           0.555468
# dtype: float64

# %%
eval_metric(grid_search_svm, X_train_count, y_train, X_test_count, y_test)
# Out:
# 	Test_Set
#               precision    recall  f1-score   support
#
#            0       0.45      0.85      0.59       820
#            1       0.96      0.77      0.85      3707
#
#     accuracy                           0.78      4527
#    macro avg       0.70      0.81      0.72      4527
# weighted avg       0.87      0.78      0.80      4527
#
#
# 	Train_Set
#               precision    recall  f1-score   support
#
#            0       0.46      0.87      0.61      3280
#            1       0.96      0.78      0.86     14824
#
#     accuracy                           0.79     18104
#    macro avg       0.71      0.82      0.73     18104
# weighted avg       0.87      0.79      0.81     18104

# %%
roc_auc_plot(grid_search_svm, y_train, X_train_count, y_test, X_test_count)

# %% [markdown]
# A big improvement from before and the model does not overfit anymore.

# %% [markdown]
# ## Random Forest
#
# ### Countvectorizer

# %%
rf_model = RandomForestClassifier()
rf_model.fit(X_train_count, y_train)
# Out:
# RandomForestClassifier()

# %%
rf_scores = eval_scores(rf_model, X_train_count, y_train)
rf_scores.mean()[2:]
# Out:
# test_accuracy      0.858926
# train_accuracy     1.000000
# test_precision     0.841788
# train_precision    1.000000
# test_recall        0.272866
# train_recall       1.000000
# test_f1            0.411845
# train_f1           1.000000
# dtype: float64

# %%
eval_metric(rf_model, X_train_count, y_train, X_test_count, y_test)
# Out:
# 	Test_Set
#               precision    recall  f1-score   support
#
#            0       0.81      0.29      0.43       820
#            1       0.86      0.98      0.92      3707
#
#     accuracy                           0.86      4527
#    macro avg       0.84      0.64      0.67      4527
# weighted avg       0.85      0.86      0.83      4527
#
#
# 	Train_Set
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3280
#            1       1.00      1.00      1.00     14824
#
#     accuracy                           1.00     18104
#    macro avg       1.00      1.00      1.00     18104
# weighted avg       1.00      1.00      1.00     18104

# %%
roc_auc_plot(rf_model, y_train, X_train_count, y_test, X_test_count)

# %% [markdown]
# ### TF-IDF

# %%
rf_model_tf = RandomForestClassifier()
rf_model_tf.fit(X_train_tf_idf, y_train)
# Out:
# RandomForestClassifier()

# %%
rf_scores_tf = eval_scores(rf_model_tf, X_train_tf_idf, y_train)
rf_scores_tf.mean()[2:]
# Out:
# test_accuracy      0.849315
# train_accuracy     1.000000
# test_precision     0.869433
# train_precision    1.000000
# test_recall        0.198171
# train_recall       1.000000
# test_f1            0.322642
# train_f1           1.000000
# dtype: float64

# %%
eval_metric(rf_model_tf, X_train_tf_idf, y_train, X_test_tf_idf, y_test)
# Out:
# 	Test_Set
#               precision    recall  f1-score   support
#
#            0       0.85      0.21      0.34       820
#            1       0.85      0.99      0.92      3707
#
#     accuracy                           0.85      4527
#    macro avg       0.85      0.60      0.63      4527
# weighted avg       0.85      0.85      0.81      4527
#
#
# 	Train_Set
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3280
#            1       1.00      1.00      1.00     14824
#
#     accuracy                           1.00     18104
#    macro avg       1.00      1.00      1.00     18104
# weighted avg       1.00      1.00      1.00     18104

# %%
roc_auc_plot(rf_model_tf, y_train, X_train_tf_idf, y_test, X_test_tf_idf)

# %% [markdown]
# It is clearly overfitted for both datasets.

# %% [markdown]
# ### Gridsearch for RandomForest

# %%
parameters_rf = {'n_estimators':[64, 128, 200],
              'max_features':[2, 4, 'sqrt'],
              'max_depth':[2, 3, 4],
              'min_samples_split':[2, 3, 4],
              'min_samples_leaf': [2,3,4],
              'class_weight':['balanced', {0:3, 1:1}],
              'max_samples':[0.8, 1]}
rf_model_gs = RandomForestClassifier()
#focus on recall
grid_search_rf = HalvingGridSearchCV(rf_model_gs, parameters_rf, max_resources=20,
                                     scoring = recall_0, cv = 5, n_jobs = -1, random_state=0)

grid_search_rf.fit(X_train_count, y_train)
best_accuracy_rf = grid_search_rf.best_score_
best_paramaeter_rf = grid_search_rf.best_params_
print("Best class 0 recall of random forest: {:.2f} %".format(best_accuracy_rf.mean()*100))
print("Best Parameter of random forest:", best_paramaeter_rf)
# Out:
# Best class 0 recall of random forest: 20.00 %
# Best Parameter of random forest: {'class_weight': 'balanced', 'max_depth': 2, 'max_features': 2, 'max_samples': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 64}

# %%
rf_scores_gs = eval_scores(grid_search_rf, X_train_count, y_train)
rf_scores_gs.mean()[2:]
# Out:
# test_accuracy      0.631676
# train_accuracy     0.643271
# test_precision     0.305760
# train_precision    0.319922
# test_recall        0.660061
# train_recall       0.680793
# test_f1            0.404079
# train_f1           0.420817
# dtype: float64

# %%
eval_metric(grid_search_rf, X_train_count, y_train, X_test_count, y_test)
# Out:
# 	Test_Set
#               precision    recall  f1-score   support
#
#            0       0.25      0.64      0.36       820
#            1       0.88      0.57      0.69      3707
#
#     accuracy                           0.58      4527
#    macro avg       0.56      0.60      0.52      4527
# weighted avg       0.76      0.58      0.63      4527
#
#
# 	Train_Set
#               precision    recall  f1-score   support
#
#            0       0.26      0.64      0.37      3280
#            1       0.88      0.59      0.71     14824
#
#     accuracy                           0.60     18104
#    macro avg       0.57      0.62      0.54     18104
# weighted avg       0.77      0.60      0.65     18104

# %%
roc_auc_plot(grid_search_rf, y_train, X_train_count, y_test, X_test_count)

# %% [markdown]
# It is not overfitted but only the recall is decent but not worth this downgrade in every aspect. Focus on f1-score next.

# %%
#try f1 score
parameters_rf = {'n_estimators':[64, 128, 200],
              'max_features':[2, 4, 'sqrt'],
              'max_depth':[5, 15, 30, 40],
              'min_samples_split':[2, 3, 4],
              'min_samples_leaf': [2,3,4],
              'class_weight':['balanced', {0:3, 1:1}],
              'max_samples':[0.8, 1]}
rf_model_gs = RandomForestClassifier()
grid_search_rf_f1 = HalvingGridSearchCV(rf_model_gs, parameters_rf, max_resources=20,
                                     scoring = f1_0, cv = 5, n_jobs = -1, random_state=0)

grid_search_rf_f1.fit(X_train_count, y_train)
best_accuracy_rf_f1 = grid_search_rf_f1.best_score_
best_paramaeter_rf_f1 = grid_search_rf_f1.best_params_
print("Best class 0 f1-score of random forest: {:.2f} %".format(best_accuracy_rf_f1.mean()*100))
print("Best Parameter of random forest:", best_paramaeter_rf_f1)
# Out:
# Best class 0 f1-score of random forest: 13.33 %
# Best Parameter of random forest: {'class_weight': 'balanced', 'max_depth': 5, 'max_features': 'sqrt', 'max_samples': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 64}

# %%
rf_scores_gs_f1 = eval_scores(grid_search_rf_f1, X_train_count, y_train)
rf_scores_gs_f1.mean()[2:]

# %% [markdown]
# (Results taken from Jupyter environment)
#
# test_accuracy      0.791204
#
# train_accuracy     0.798761
#
# test_precision     0.546724
#
# train_precision    0.546367
#
# test_recall        0.509146
#
# train_recall       0.536814
#
# test_f1            0.419436
#
# train_f1           0.439262
#
# dtype: float64

# %%
eval_metric(grid_search_rf_f1, X_train_count, y_train, X_test_count, y_test)
# Out:
# 	Test_Set
#               precision    recall  f1-score   support
#
#            0       0.47      0.69      0.56       820
#            1       0.92      0.83      0.87      3707
#
#     accuracy                           0.80      4527
#    macro avg       0.70      0.76      0.72      4527
# weighted avg       0.84      0.80      0.82      4527
#
#
# 	Train_Set
#               precision    recall  f1-score   support
#
#            0       0.52      0.77      0.62      3280
#            1       0.94      0.84      0.89     14824
#
#     accuracy                           0.83     18104
#    macro avg       0.73      0.80      0.75     18104
# weighted avg       0.86      0.83      0.84     18104

# %%
roc_auc_plot(grid_search_rf_f1, y_train, X_train_count, y_test, X_test_count)

# %% [markdown]
# The recall remained in the 60s while every other metric improved.

# %% [markdown]
# ## Ada Boosting
#
# ### Countvectorizer

# %%
ada = AdaBoostClassifier()
ada.fit(X_train_count, y_train)
# Out:
# AdaBoostClassifier()

# %%
ada_scores = eval_scores(ada, X_train_count, y_train)
ada_scores.mean()[2:]
# Out:
# test_accuracy      0.862627
# train_accuracy     0.863525
# test_precision     0.684045
# train_precision    0.687029
# test_recall        0.449390
# train_recall       0.453125
# test_f1            0.542345
# train_f1           0.546069
# dtype: float64

# %%
eval_metric(ada, X_train_count, y_train, X_test_count, y_test)
# Out:
# 	Test_Set
#               precision    recall  f1-score   support
#
#            0       0.68      0.46      0.55       820
#            1       0.89      0.95      0.92      3707
#
#     accuracy                           0.86      4527
#    macro avg       0.79      0.71      0.74      4527
# weighted avg       0.85      0.86      0.85      4527
#
#
# 	Train_Set
#               precision    recall  f1-score   support
#
#            0       0.69      0.45      0.55      3280
#            1       0.89      0.95      0.92     14824
#
#     accuracy                           0.86     18104
#    macro avg       0.79      0.70      0.73     18104
# weighted avg       0.85      0.86      0.85     18104

# %%
roc_auc_plot(ada, y_train, X_train_count, y_test, X_test_count)

# %% [markdown]
# ### TF-IDF

# %%
ada_tf = AdaBoostClassifier()
ada_tf.fit(X_train_tf_idf, y_train)
# Out:
# AdaBoostClassifier()

# %%
ada_scores_tf = eval_scores(ada_tf, X_train_tf_idf, y_train)
ada_scores_tf.mean()[2:]
# Out:
# test_accuracy      0.858705
# train_accuracy     0.865582
# test_precision     0.664778
# train_precision    0.691366
# test_recall        0.444207
# train_recall       0.466235
# test_f1            0.532458
# train_f1           0.556875
# dtype: float64

# %%
eval_metric(ada_tf, X_train_tf_idf, y_train, X_test_tf_idf, y_test)
# Out:
# 	Test_Set
#               precision    recall  f1-score   support
#
#            0       0.67      0.46      0.54       820
#            1       0.89      0.95      0.92      3707
#
#     accuracy                           0.86      4527
#    macro avg       0.78      0.70      0.73      4527
# weighted avg       0.85      0.86      0.85      4527
#
#
# 	Train_Set
#               precision    recall  f1-score   support
#
#            0       0.68      0.46      0.55      3280
#            1       0.89      0.95      0.92     14824
#
#     accuracy                           0.86     18104
#    macro avg       0.79      0.71      0.74     18104
# weighted avg       0.85      0.86      0.85     18104

# %%
roc_auc_plot(ada_tf, y_train, X_train_tf_idf, y_test, X_test_tf_idf)

# %% [markdown]
# The model is not overfitting but I think I can imporve it with gridsearch.

# %% [markdown]
# ### Gridsearch for Adaboost

# %%
#showing hyperparameters
# Out:
# {'algorithm': 'SAMME.R',
#  'base_estimator': None,
#  'learning_rate': 1.0,
#  'n_estimators': 50,
#  'random_state': None}

# %%
parameters_ada = {'algorithm': ['SAMME', 'SAMME.R'], 'base_estimator__min_samples_split':[2,3,4,5,6,7,8,9],
         'base_estimator__min_samples_leaf':[1,2,3,4,5,6,7,8,9],
         'base_estimator__max_depth':[2,3,4,5,6,7],'n_estimators': [100,200,300,400,500],
         'learning_rate':[0.01,0.1]}

ada_gs = AdaBoostClassifier(base_estimator=DecisionTreeClassifier())

grid_search_ada = HalvingGridSearchCV(ada_gs, parameters_ada, max_resources=20, scoring = recall_0,
                                      cv = 5, n_jobs = -1)
#grid_search_lr = GridSearchCV(estimator = logistic_model_gs, param_grid = parameters_lr,
#                              scoring = f1_0, cv = 5, n_jobs = -1)

grid_search_ada.fit(X_train_tf_idf, y_train)
best_accuracy_ada = grid_search_ada.best_score_
best_paramaeter_ada = grid_search_ada.best_params_
print("Best class 0 recall for adaboost: {:.2f} %".format(best_accuracy_ada.mean()*100))
print("Best Parameter of adaboost:", best_paramaeter_ada)
# Out:
# Best class 0 recall for adaboost: 30.00 %
# Best Parameter of adaboost: {'algorithm': 'SAMME', 'base_estimator__max_depth': 2, 'base_estimator__min_samples_leaf': 1, 'base_estimator__min_samples_split': 2, 'learning_rate': 0.01, 'n_estimators': 100}

# %%
ada_scores_gs = eval_scores(grid_search_ada, X_train_tf_idf, y_train)
ada_scores_gs.mean()[2:]
# Out:
# test_accuracy      0.826612
# train_accuracy     0.828850
# test_precision     0.430410
# train_precision    0.473452
# test_recall        0.068598
# train_recall       0.072027
# test_f1            0.115940
# train_f1           0.121319
# dtype: float64

# %%
eval_metric(grid_search_ada, X_train_tf_idf, y_train, X_test_tf_idf, y_test)
# Out:
# 	Test_Set
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       820
#            1       0.82      1.00      0.90      3707
#
#     accuracy                           0.82      4527
#    macro avg       0.41      0.50      0.45      4527
# weighted avg       0.67      0.82      0.74      4527
#
#
# 	Train_Set
# D:\anacnda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\anacnda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
roc_auc_plot(grid_search_ada, y_train, X_train_tf_idf, y_test, X_test_tf_idf)

# %% [markdown]
# It couldn't classify class 0. Keep the vanilla adaboost model instead.

# %% [markdown]
# ## DL modeling

# %%
X_dl = prep_df["clean"]
y_dl = prep_df["recommended"]

# %% [markdown]
# ### Tokenization

# %%
temp['count'].sum()
# Out:
# 1363325

# %%
temp['count'].value_counts()
# Out:
# 96     442
# 95     427
# 99     404
# 97     403
# 98     388
#       ...
# 2        8
# 114      4
# 113      4
# 112      4
# 115      1
# Name: count, Length: 114, dtype: int64

# %%
#I'll try to get all words first since the dataset is cleaned
num_words = 1363326
#if assigned to none, we will get an error in the DL modeling part
tokenizer = Tokenizer(num_words=num_words)

# %%
tokenizer.fit_on_texts(X_dl)

# %% [markdown]
# ### Creating word index

# %%
#words based on frequency
tokenizer.word_index
# Out:
# {'dress': 1,
#  'fit': 2,
#  'size': 3,
#  'love': 4,
#  'top': 5,
#  'like': 6,
#  'color': 7,
#  'look': 8,
#  'wear': 9,
#  'great': 10,
#  'im': 11,
#  'would': 12,
#  'fabric': 13,
#  'small': 14,
#  'really': 15,
#  'ordered': 16,
#  'little': 17,
#  'perfect': 18,
#  'one': 19,
#  'flattering': 20,
#  'soft': 21,
#  'well': 22,
#  'back': 23,
#  'comfortable': 24,
#  'cute': 25,
#  'nice': 26,
#  'bought': 27,
#  'beautiful': 28,
#  'bit': 29,
#  'material': 30,
#  'large': 31,
#  'shirt': 32,
#  'much': 33,
#  'sweater': 34,
#  'length': 35,
#  'run': 36,
#  'jean': 37,
#  'also': 38,
#  'work': 39,
#  'petite': 40,
#  'got': 41,
#  'long': 42,
#  'short': 43,
#  'waist': 44,
#  'quality': 45,
#  'medium': 46,
#  'skirt': 47,
#  'think': 48,
#  'pretty': 49,
#  'even': 50,
#  'retailer': 51,
#  'x': 52,
#  'make': 53,
#  'feel': 54,
#  'tried': 55,
#  'pant': 56,
#  'store': 57,
#  'usually': 58,
#  'get': 59,
#  'way': 60,
#  'sleeve': 61,
#  'good': 62,
#  'could': 63,
# ...

# %%
#check if we tokenize too many words or not
len(tokenizer.word_index)
# Out:
# 11996

# %% [markdown]
# ### Converting tokens to numeric

# %%
X_num_tokens = tokenizer.texts_to_sequences(X_dl)

# %% [markdown]
# ### Maximum number of tokens for all documents¶

# %%
#storing length of each token (need to have the same dimensions before feeding it to DL models)
num_tokens = [len(sen_tokens) for sen_tokens in X_num_tokens]
num_tokens = np.array(num_tokens)

# %%
num_tokens.max()
# Out:
# 58

# %%
num_tokens.mean()
# Out:
# 28.3267199858601

# %%
num_tokens.sum()
# Out:
# 641062

# %% [markdown]
# I don't want to cut some of the words to half their length so I'm going to do padding for words less than max tokens.

# %% [markdown]
# ### Fixing token counts of all documents (pad_sequences)

# %%
#visualizing tokens
plt.hist(num_tokens, bins=30, edgecolor='black')  # Adjust the number of bins as needed
plt.title("Distribution of Token Numbers")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# I can cut it to 50 tokens but I want to keep all tokens and see the results it would produce.

# %%
#choose max if u have a strong device
max_tokens = 58
X_pad = pad_sequences(X_num_tokens, maxlen=max_tokens, padding="pre")

# %%
#making sure reviews are fixed to the same number of tokens
X_pad.shape
# Out:
# (22631, 58)

# %% [markdown]
# ### Train Set Split

# %%
X_train_dl, X_test_dl, y_train_dl, y_test_dl = train_test_split(X_pad, y_dl, test_size=0.2,
                                                    stratify=y_dl, random_state=42)
X_train_vdl, X_val_dl, y_train_vdl, y_val_dl = train_test_split(X_train_dl, y_train_dl,
                                                                test_size=0.2,
                                                    stratify=y_train_dl, random_state=42)

# %% [markdown]
# ### Modeling

# %%
early_stop = tf.keras.callbacks.EarlyStopping(monitor="val_recall", mode="max", verbose=1, patience = 5, restore_best_weights=True)

# %%
lstm_model = Sequential()
#input_dim = what we fed the tokenizer
#output_dim = choose whatever but bigger number means bigger computation (give the first layer the same number of neurons)
#input_length = longest token
lstm_model.add(Embedding(input_dim=num_words, output_dim=58, input_length=max_tokens))

lstm_model.add(Dropout(0.4))

lstm_model.add(tf.keras.layers.LSTM(units=58, return_sequences=True))
lstm_model.add(Dropout(0.40))
lstm_model.add(tf.keras.layers.LSTM(units=24, return_sequences=False))

lstm_model.add(Dense(1, activation='sigmoid'))

# %%
lstm_model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate = 0.003), metrics=['Recall'])
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 58, 58)            79072908
#
#  dropout_114 (Dropout)       (None, 58, 58)            0
#
#  lstm (LSTM)                 (None, 58, 58)            27144
#
#  dropout_115 (Dropout)       (None, 58, 58)            0
#
#  lstm_1 (LSTM)               (None, 24)                7968
#
#  dense_3 (Dense)             (None, 1)                 25
#
# ...
# Total params: 79108045 (301.77 MB)
# Trainable params: 79108045 (301.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
lstm_model.fit(X_train_vdl, y_train_vdl, epochs=20, batch_size=32, validation_data=(X_val_dl, y_val_dl), callbacks=[early_stop])
# Out:
# Epoch 1/20
# 453/453 [==============================] - 153s 323ms/step - loss: 0.3115 - recall: 0.9494 - val_loss: 0.2656 - val_recall: 0.9268
# Epoch 2/20
# 453/453 [==============================] - 140s 310ms/step - loss: 0.2159 - recall: 0.9511 - val_loss: 0.2735 - val_recall: 0.9663
# Epoch 3/20
# 453/453 [==============================] - 141s 311ms/step - loss: 0.1731 - recall: 0.9594 - val_loss: 0.2972 - val_recall: 0.9383
# Epoch 4/20
# 453/453 [==============================] - 145s 321ms/step - loss: 0.1357 - recall: 0.9703 - val_loss: 0.3515 - val_recall: 0.9275
# Epoch 5/20
# 453/453 [==============================] - 138s 304ms/step - loss: 0.1121 - recall: 0.9761 - val_loss: 0.3502 - val_recall: 0.9288
# Epoch 6/20
# 453/453 [==============================] - 140s 309ms/step - loss: 0.0958 - recall: 0.9797 - val_loss: 0.3968 - val_recall: 0.9231
# Epoch 7/20
# ...

# %%
lstm_model_loss = pd.DataFrame(lstm_model.history.history)
lstm_model_loss.plot();

# %%
eval_metric(lstm_model, X_train_dl, y_train_dl, X_test_dl, y_test_dl, dl = True)
# Out:
# ...
# 142/142 [==============================] - 2s 12ms/step
# 	Test_Set
#               precision    recall  f1-score   support
#
#            0       0.76      0.55      0.64       820
#            1       0.91      0.96      0.93      3707
#
#     accuracy                           0.89      4527
#    macro avg       0.83      0.76      0.79      4527
# weighted avg       0.88      0.89      0.88      4527
#
#
# 	Train_Set
#               precision    recall  f1-score   support
#
#            0       0.87      0.72      0.79      3280
#            1       0.94      0.98      0.96     14824
#
#     accuracy                           0.93     18104
#    macro avg       0.91      0.85      0.87     18104
# weighted avg       0.93      0.93      0.93     18104

# %%
roc_auc_plot(lstm_model, y_train_dl, X_train_dl, y_test_dl, X_test_dl)
# Out:
# ...
# 142/142 [==============================] - 2s 12ms/step

# %% [markdown]
# The slightest overfit I could get.

# %%
y_pred_lstm_train = lstm_model.predict(X_train_dl)
y_pred_lstm_train = y_pred_lstm_train >0.5
y_pred_lstm_test = lstm_model.predict(X_test_dl)
y_pred_lstm_test = y_pred_lstm_test >0.5
# Out:
# ...
# 142/142 [==============================] - 2s 13ms/step

# %%
lstm_scores = eval_scores_dl(y_train_dl, y_pred_lstm_train)
lstm_scores
# Out:
#         f-1  precision    recall
# 0  0.927976   0.937871  0.930623

# %%
lstm_scores_test = eval_scores_dl(y_test_dl, y_pred_lstm_test)
lstm_scores_test
# Out:
#         f-1  precision    recall
# 0  0.879731   0.902857  0.887122

# %% [markdown]
# Evaluating the metrics shows that there is no overfitting.

# %% [markdown]
# ### GRU Model

# %%
dl_model = Sequential()
#input_dim = what we fed the tokenizer
#output_dim = choose whatever but bigger number means bigger computation (give the first layer the same number of neurons)
#input_length = longest token
dl_model.add(Embedding(input_dim=num_words, output_dim=58, input_length=max_tokens))

dl_model.add(Dropout(0.4))

dl_model.add(GRU(units=58, return_sequences=True))
dl_model.add(Dropout(0.40))
dl_model.add(GRU(units=24, return_sequences=False))

#dl_model.add(GRU(units=15, return_sequences=True))

#dl_model.add(GRU(units=7, return_sequences=False))

dl_model.add(Dense(1, activation='sigmoid'))

# %%
dl_model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate = 0.003), metrics=['Recall'])
dl_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_2 (Embedding)     (None, 58, 58)            79072908
#
#  dropout_118 (Dropout)       (None, 58, 58)            0
#
#  gru_2 (GRU)                 (None, 58, 58)            20532
#
#  dropout_119 (Dropout)       (None, 58, 58)            0
#
#  gru_3 (GRU)                 (None, 24)                6048
#
#  dense_5 (Dense)             (None, 1)                 25
#
# ...
# Total params: 79099513 (301.74 MB)
# Trainable params: 79099513 (301.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
dl_model.fit(X_train_vdl, y_train_vdl, epochs=20, batch_size=32, validation_data=(X_val_dl, y_val_dl), callbacks=[early_stop])
# Out:
# Epoch 1/20
# 453/453 [==============================] - 150s 319ms/step - loss: 0.3164 - recall: 0.9511 - val_loss: 0.2713 - val_recall: 0.9690
# Epoch 2/20
# 453/453 [==============================] - 145s 320ms/step - loss: 0.2077 - recall: 0.9541 - val_loss: 0.2979 - val_recall: 0.9767
# Epoch 3/20
# 453/453 [==============================] - 140s 310ms/step - loss: 0.1575 - recall: 0.9645 - val_loss: 0.3034 - val_recall: 0.9582
# Epoch 4/20
# 453/453 [==============================] - 141s 312ms/step - loss: 0.1202 - recall: 0.9755 - val_loss: 0.3705 - val_recall: 0.9649
# Epoch 5/20
# 453/453 [==============================] - 140s 309ms/step - loss: 0.0959 - recall: 0.9791 - val_loss: 0.3856 - val_recall: 0.9376
# Epoch 6/20
# 453/453 [==============================] - 138s 305ms/step - loss: 0.0735 - recall: 0.9835 - val_loss: 0.4699 - val_recall: 0.9315
# Epoch 7/20
# ...

# %% [markdown]
# ### Model Evaluation

# %%
dl_model_loss = pd.DataFrame(dl_model.history.history)
dl_model_loss.plot();

# %%
eval_metric(dl_model, X_train_dl, y_train_dl, X_test_dl, y_test_dl, dl = True)
# Out:
# ...
# 142/142 [==============================] - 1s 10ms/step
# 	Test_Set
#               precision    recall  f1-score   support
#
#            0       0.79      0.46      0.58       820
#            1       0.89      0.97      0.93      3707
#
#     accuracy                           0.88      4527
#    macro avg       0.84      0.72      0.76      4527
# weighted avg       0.87      0.88      0.87      4527
#
#
# 	Train_Set
#               precision    recall  f1-score   support
#
#            0       0.91      0.65      0.76      3280
#            1       0.93      0.99      0.96     14824
#
#     accuracy                           0.92     18104
#    macro avg       0.92      0.82      0.86     18104
# weighted avg       0.92      0.92      0.92     18104

# %%
roc_auc_plot(dl_model, y_train_dl, X_train_dl, y_test_dl, X_test_dl)
# Out:
# ...
# 142/142 [==============================] - 1s 10ms/step

# %%
y_pred_gru_train = dl_model.predict(X_train_dl)
y_pred_gru_train = y_pred_gru_train >0.5
y_pred_gru_test = dl_model.predict(X_test_dl)
y_pred_gru_test = y_pred_gru_test >0.5
# Out:
# ...
# 142/142 [==============================] - 2s 11ms/step

# %%
gru_scores = eval_scores_dl(y_test_dl, y_pred_gru_test)
gru_scores
# Out:
#         f-1  precision    recall
# 0  0.867039   0.888727  0.880274

# %%
gru_scores_train = eval_scores_dl(y_train_dl, y_pred_gru_train)
gru_scores_train
# Out:
#         f-1  precision    recall
# 0  0.919276   0.924892  0.924547

# %% [markdown]
# Confusion matrix shows overfitting while other evaluation functions deny it.

# %% [markdown]
# ## BERT Modeling

# %%
#!pip install transformers

# %% [markdown]
# ### Read Data

# %%
chart = sns.countplot(x= "recommended", data=prep_df)
chart.bar_label(chart.containers[0])
plt.title("Number of texts for recommendation");

# %% [markdown]
# Huge imbalance as expected.

# %% [markdown]
# ### Train test split

# %%
X_train_bert, X_test_bert, y_train_bert, y_test_bert = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train_vbert, X_val_bert, y_train_vbert, y_val_bert = train_test_split(X_train_bert,
                                                                        y_train_bert, test_size=0.2,
                                                                        stratify=y_train_bert, random_state=42)

# %% [markdown]
# ### Tokenization

# %%
#from transformers import BertTokenizer
#in general, people don't care about capitalization when typing reviews
bert_tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %% [markdown]
# ### Fixing token counts of all documents

# %% [markdown]
# Done below.

# %% [markdown]
# ### Transformation Vectors to Matrices

# %%
def transformation(X, tokenizer):
    seq_len = max_tokens
    Xids = []
    Xmask = []
    for text in X:
        tokens = tokenizer.encode_plus(text, max_length=seq_len, truncation=True,      # we use tokenizer2 for uncased
                                      padding='max_length', add_special_tokens=True)
        Xids.append(tokens['input_ids']) # We are appending the input_ids vector corresponding to each line/document to the Xids list.
        Xmask.append(tokens['attention_mask']) # We are appending the attention_mask vector corresponding to each line/document to the Xmask list.
    return np.array(Xids), np.array(Xmask)

# %%
Xids_train_v, Xmask_train_v = transformation(X_train_vbert, bert_tokenizer)
Xids_val, Xmask_val = transformation(X_val_bert, bert_tokenizer)
Xids_train, Xmask_train = transformation(X_train_bert, bert_tokenizer)
Xids_test, Xmask_test = transformation(X_test_bert, bert_tokenizer)

# %% [markdown]
# ### Transformation Matrix to Tensorflow tensor

# %%
dataset_trainv = tf.data.Dataset.from_tensor_slices((Xids_train_v, Xmask_train_v, y_train_vbert))
dataset_val = tf.data.Dataset.from_tensor_slices((Xids_val, Xmask_val, y_val_bert))
dataset_train = tf.data.Dataset.from_tensor_slices((Xids_train, Xmask_train, y_train_bert))
dataset_test = tf.data.Dataset.from_tensor_slices((Xids_test, Xmask_test, y_test_bert))

# %%
def map_func(Tensor_Xids, Tensor_Xmask, Tensor_labels):
    # we convert our three-item tuple into a two-item tuple where the input item is a dictionary
    return {'input_ids': Tensor_Xids, 'attention_mask': Tensor_Xmask}, Tensor_labels

# Which of the tensors we obtained above is 'input_ids', which is 'attention_mask', and which is 'labels' the model does not know. Therefore, we need
# to provide this information to our model. We define the map_func function for this purpose.

# %%
dataset_trainv = dataset_trainv.map(map_func)
dataset_val = dataset_val.map(map_func)
dataset_train = dataset_train.map(map_func)
dataset_test = dataset_test.map(map_func)

# %% [markdown]
# ### Batch Size

# %%
batch_size = 32
trainv_ds = dataset_trainv.batch(batch_size)
val_ds = dataset_val.batch(batch_size)
train_ds = dataset_train.batch(batch_size)
test_ds = dataset_test.batch(batch_size)

# %%
#!pip install -q tf-models-official
# Out:
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'D:\\anacnda3\\Lib\\site-packages\\~umpy.libs\\libopenblas64__v0.3.23-293-gc2f4bdbb-gcc_10_3_0-2bde3a66a51006b2b53eb373ff767a3f.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)

# %%
#pip install tf-models-official
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# ...

# %%
#import tensorflow_models as tfm

# %%
#pip install gin-config==0.1.1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)

# %%
#pip install tensorflow-addons==0.16.1
# Out:
# ...
#   Attempting uninstall: tensorflow-addons
#     Found existing installation: tensorflow-addons 0.22.0
#     Uninstalling tensorflow-addons-0.22.0:
#       Successfully uninstalled tensorflow-addons-0.22.0
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)

# %%
#pip install -U "tensorflow-text==2.10.0"
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# ...
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# ...
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.2
#     Uninstalling tensorboard-data-server-0.7.2:
#       Successfully uninstalled tensorboard-data-server-0.7.2
# ...

# %%
#pip install "tf-models-official==2.10.0"
# Out:
# ...
#   Using cached opencv_python_headless-4.5.2.52-cp39-cp39-win_amd64.whl (34.6 MB)
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
#   Attempting uninstall: tf-models-official
#     Found existing installation: tf-models-official 2.10.1
#     Uninstalling tf-models-official-2.10.1:
#       Successfully uninstalled tf-models-official-2.10.1
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# ...

# %%
#import struct
#print(struct.calcsize("P")*8)
# Out:
# 64

# %%
epochs = 3

steps_per_epoch = len(trainv_ds)

num_train_steps = steps_per_epoch * epochs
num_warmup_steps = int(0.1*num_train_steps)

init_lr = 5e-5 #2e-5  # 3e-5, 5e-5
optimizer= optimization.create_optimizer(init_lr=init_lr,
                                          num_train_steps=num_train_steps,
                                          num_warmup_steps=num_warmup_steps,
                                          optimizer_type= ('adamw'))

# %%
#pip install tensorflow==2.8.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'D:\\anacnda3\\Lib\\site-packages\\tensorflow\\lite\\experimental\\microfrontend\\python\\ops\\_audio_microfrontend_op.so'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# ...

# %%
#pip install tensorflow==2.10.0
# Out:
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'D:\\anacnda3\\Lib\\site-packages\\tensorflow\\lite\\experimental\\microfrontend\\python\\ops\\_audio_microfrontend_op.so'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anacnda3\lib\site-packages)
# ...
#   Using cached tensorflow-2.8.0-cp39-cp39-win_amd64.whl (438.0 MB)
# ...
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.10.1
#     Uninstalling tensorflow-2.10.1:
# ...

# %% [markdown]
# ### Creating optimization

# %%
#f1-score needs to be manually calculated to use
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
def create_model():


    model =  TFBertModel.from_pretrained("bert-base-uncased")

    input_ids = Input(shape=(58,), name='input_ids', dtype='int32')
    attention_mask = Input(shape=(58,), name='attention_mask', dtype='int32')

    embeddings = model.bert(input_ids=input_ids, attention_mask=attention_mask)["pooler_output"]

    x = Dense(58, activation='relu')(embeddings)
    x = BatchNormalization()(x)
    x = Dropout(0.1)(x) # The recommended ratio by developers is 0.1.
    y = Dense(1, activation='sigmoid', name='outputs')(x) # Returning the output


    return Model(inputs=[input_ids, attention_mask], outputs=y)

# %% [markdown]
# ### Creating Model with TPU

# %%
with strategy.scope():

  bert_model = create_model()
  bert_model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate = 0.003), metrics=['Recall'])
bert_model.summary()
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# ...

# %% [markdown]
# ### Model Fiting

# %%
bert_model.fit(trainv_ds, epochs=20, validation_data=(val_ds), callbacks=[early_stop])
# Out:
# Epoch 1/20
# 453/453 [==============================] - 45s 99ms/step - loss: 0.4742 - recall: 1.0000 - val_loss: 2.4104 - val_recall: 1.0000
# Epoch 2/20
# 453/453 [==============================] - 40s 87ms/step - loss: 0.4739 - recall: 1.0000 - val_loss: 0.6338 - val_recall: 1.0000
# Epoch 3/20
# 453/453 [==============================] - 41s 91ms/step - loss: 0.4738 - recall: 1.0000 - val_loss: 0.8285 - val_recall: 1.0000
# Epoch 4/20
# 453/453 [==============================] - 40s 87ms/step - loss: 0.4739 - recall: 1.0000 - val_loss: 0.6719 - val_recall: 1.0000
# Epoch 5/20
# 453/453 [==============================] - 39s 87ms/step - loss: 0.4736 - recall: 1.0000 - val_loss: 0.4867 - val_recall: 1.0000
# Epoch 6/20
# ...
# 453/453 [==============================] - 49s 108ms/step - loss: 0.4743 - recall: 1.0000 - val_loss: 0.4750 - val_recall: 1.0000
# Epoch 6: early stopping

# %% [markdown]
# ### Model evaluation

# %%
bert_loss = pd.DataFrame(bert_model.history.history)
bert_loss.plot();

# %%
bert_model.evaluate(train_ds)
# Out:
# 566/566 [==============================] - 19s 28ms/step - loss: 2.4103 - recall: 1.0000
# [2.410252094268799, 1.0]

# %%
bert_model.evaluate(test_ds)
# Out:
# 142/142 [==============================] - 6s 31ms/step - loss: 2.4097 - recall: 1.0000
# [2.409722089767456, 1.0]

# %%
eval_metric(bert_model, train_ds, y_train_bert, test_ds, y_test_bert, dl = True)
# Out:
# ...
# 142/142 [==============================] - 4s 20ms/step
# 	Test_Set
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# Could not classify class 0. Need to evaluate it using custom evaluation function.

# %%
y_pred_train_bert = bert_model.predict(train_ds)
# Out:
# 566/566 [==============================] - 13s 21ms/step

# %%
y_pred_train_bert = y_pred_train_bert >0.5
f1_score_bert_train = f1_score(y_train_bert, y_pred_train_bert, average='weighted', labels=np.unique(y_pred_train_bert))
f1_score_bert_train
# Out:
# 0.9003887269193392

# %%
y_pred_test_bert = bert_model.predict(test_ds)
# Out:
# 142/142 [==============================] - 5s 21ms/step

# %%
y_pred_test_bert = y_pred_test_bert >0.5
f1_score_bert_test = f1_score(y_test_bert, y_pred_test_bert, average='weighted', labels=np.unique(y_pred_test_bert))
f1_score_bert_test
# Out:
# 0.9004129220306047

# %%
recall_bert_test = recall_score(y_test_bert, y_pred_test_bert, average='weighted', labels=np.unique(y_pred_test_bert))
recall_bert_test
# Out:
# 1.0

# %%
recall_bert_train = recall_score(y_train_bert, y_pred_train_bert, average='weighted', labels=np.unique(y_pred_train_bert))
recall_bert_train
# Out:
# 1.0

# %%
precision_bert = average_precision_score(y_train_bert, y_pred_train_bert)
precision_bert
# Out:
# 0.8188245691559877

# %%
precision_bert_test = average_precision_score(y_test_bert, y_pred_test_bert)
precision_bert_test
# Out:
# 0.8188645902363596

# %%
bert_scores = eval_scores_dl(y_test_bert, y_pred_test_bert)
bert_scores
# Out:
#         f-1  precision  recall
# 0  0.900413   0.818865     1.0

# %%
bert_scores_train = eval_scores_dl(y_train_bert, y_pred_train_bert)
bert_scores_train
# Out:
#         f-1  precision  recall
# 0  0.900389   0.818825     1.0

# %%
roc_auc_plot(bert_model, y_train_bert, train_ds, y_test_bert, test_ds)
# Out:
# ...
# 142/142 [==============================] - 4s 22ms/step

# %% [markdown]
# Because it could not predict class 0.

# %% [markdown]
# ### Compare Models F1 Scores, Recall Scores and Average Precision Score

# %% [markdown]
# ### DL Models

# %%
models_scores = pd.DataFrame({'Models':
                              ['GRU', 'LSTM', 'BERT'],
                              'F1-Score':[gru_scores['f-1'][0], lstm_scores_test['f-1'][0], bert_scores['f-1'][0]],
                              'Precision':[gru_scores['precision'][0], lstm_scores_test['precision'][0],
                                           bert_scores['precision'][0]],
                              'Recall':[gru_scores['recall'][0], lstm_scores_test['recall'][0], bert_scores['recall'][0]]})

# %%
sns.barplot(data = models_scores, x = 'Models', y = 'F1-Score')
plt.title('F1 Scores in Deep Learning Models')
plt.tight_layout();

# %% [markdown]
# All of the deep learning models produced excellent f1-score results but BERT model performed best by a small margin.

# %%
sns.barplot(data = models_scores, x = 'Models', y = 'Recall')
plt.title('Recall Scores in Deep Learning Models')
plt.tight_layout();

# %% [markdown]
# BERT model performed best but can't trust the results since it couldn't identify class 0 so I think LSTM is the best performing model here.

# %%
sns.barplot(data = models_scores, x = 'Models', y = 'Precision')
plt.title('Average Precision in Deep Learning Models')
plt.tight_layout();

# %% [markdown]
# LSTM model performed the best in precision while BERT model performed the worst.

# %% [markdown]
# ### ML Models

# %%
#typed values manually from jupyter environment because I ran out of TPU in Google Colab. Sorry for the inconvenience
ml_models_scores = pd.DataFrame({'Models':
                              ['Logistic', 'NB', 'SVM', 'RF', 'Adaboost'],
                              'F1-Score':[0.637918, 0.682225, 0.420881, 0.419436, 0.542345],
                              'Precision':[0.514741, 0.642721, 0.479499, 0.546724, 0.684045],
                              'Recall':[0.840244, 0.727134, 0.626220, 0.509146, 0.449390]})

# %%
sns.barplot(data = ml_models_scores, x = 'Models', y = 'F1-Score')
plt.title('F1 Scores in Machine Learning Models')
plt.tight_layout();

# %% [markdown]
# The best model for f1-score is NB while the least performing is the optimized random forest.

# %%
sns.barplot(data = ml_models_scores, x = 'Models', y = 'Precision')
plt.title('Precision Scores in Machine Learning Models')
plt.tight_layout();

# %% [markdown]
# The vanilla adaboost model has the best precision but it is not our focus in this problem.

# %%
sns.barplot(data = ml_models_scores, x = 'Models', y = 'Recall')
plt.title('Recall Scores in Machine Learning Models')
plt.tight_layout();

# %% [markdown]
# The optimized logistic regression model has the best performance in recall which is out main focus.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# - In general, deep learning models performed better than machine learning models and the strongest deep learning model was LSTM.
# - In the machine learning models, the optimized logistic regression was the best choice for our problem because it performs best in recall and is balanced in other metrics.

# %% [markdown]
# ### References:
#
# - https://www.pickfu.com/demographic-segmentation
#
# - https://stackoverflow.com/questions/49382207/how-to-map-numeric-data-into-categories-bins-in-pandas-dataframe
#
# - https://stackoverflow.com/questions/55997720/how-to-get-best-estimator-parameters-using-adaboost-and-gridsearchcv
#
# - https://towardsdatascience.com/7-tips-to-choose-the-best-optimizer-47bb9c1219e

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
